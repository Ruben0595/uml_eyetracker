# %%
import functions
from sklearn.cluster import KMeans
import numpy as np
import pandas as pd

# %%
task_n = 'all'

# %%
df = functions.file_opener(task = task_n, labeler = 'all')

# %%
task = df.task
df = df.drop('task', axis = 1)
#labels = labels.astype(int)

# %%
df.shape
# Out:
# (150854, 7)

# %%
balanced = pd.DataFrame()
clus = {}
for i in df.label.unique():
    print(float(i))
    balanced = pd.concat([balanced, df.loc[df['label'] == float(i)].sample(min(df.label.value_counts()))])
    clus[int(i)] = 0
    print(clus)
# Out:
# 3.0
# {3: 0}
# 2.0
# {3: 0, 2: 0}
# 0.0
# {3: 0, 2: 0, 0: 0}
# 1.0
# {3: 0, 2: 0, 0: 0, 1: 0}

# %%
df.label.value_counts()
# Out:
# 3.0    83025
# 0.0    43609
# 2.0    14507
# 1.0     9713
# Name: label, dtype: int64

# %%
balanced.label.value_counts()
# Out:
# 3.0    9713
# 2.0    9713
# 0.0    9713
# 1.0    9713
# Name: label, dtype: int64

# %%
labels = balanced.label.to_numpy()
df = balanced.drop('label', axis = 1)

# %%
functions.normalize(df)
# Out:
#               0         1         2         3         4         5
# 12649  0.000012  0.206778  0.189517  0.484039  0.376300  0.434350
# 2620   0.000010  0.584151  0.189996  0.483150  0.500677  0.497845
# 5509   0.000016  0.697427  0.189700  0.483487  0.365229  0.646640
# 6730   0.000003  0.626751  0.191345  0.481606  0.200862  0.338756
# 34129  0.000009  0.841768  0.189998  0.484639  0.386408  0.490746
# ...         ...       ...       ...       ...       ...       ...
# 15432  0.000006  0.574304  0.190032  0.484678  0.509385  0.537132
# 28351  0.000336  0.275941  0.189514  0.484107  0.483173  0.504873
# 11474  0.000002  0.194793  0.189474  0.484041  0.408653  0.519402
# 17218  0.000017  0.314976  0.189724  0.484326  0.478162  0.540147
# 7094   0.000596  0.252258  0.189611  0.484059  0.550357  0.681430
#
# [38852 rows x 6 columns]

# %%
clusters = {}
cluster_number = 50
for i in range(0, cluster_number):
    clusters[i] = {0:0, 1:0, 2:0, 3:0}

# %%
from sklearn.cluster import AgglomerativeClustering, SpectralClustering
kmeans = KMeans(n_clusters=cluster_number, random_state=0, n_init="auto").fit(df)
#clustering = AgglomerativeClustering(n_clusters=cluster_number).fit(df)
#clustering = SpectralClustering(n_clusters=cluster_number, n_jobs=-1).fit(df)

# %%
predicted = kmeans.labels_
#predicted = clustering.labels_

print(len(labels))
len(predicted)
# Out:
# 38852
# 38852

# %%
for i, cluster in enumerate(predicted):
    clusters[cluster][labels[i]] += 1

# %%
from matplotlib import pyplot as plt
events = [0,1,2,3]
cluster_numbers = [10,50,100]


for cluster_number in cluster_numbers:
    clusters = {}

    for event in events:
        for i in range(0, cluster_number):
            clusters[i] = {0:0, 1:0, 2:0, 3:0}

        kmeans = KMeans(n_clusters=cluster_number, random_state=0, n_init="auto").fit(df)
        predicted = kmeans.labels_
        centers = kmeans.cluster_centers_

        for i, cluster in enumerate(predicted):
            clusters[cluster][labels[i]] += 1

        dist_dict = {}
        for i, cluster in enumerate(clusters.values()):
            dist_dict[i] = (cluster[event])

        distlist = list(dist_dict.values())
        plt.plot(distlist, label = event)
    plt.ylabel("Number of datapoints")
    plt.xlabel("Cluster")
    plt.legend()
    plt.title('number of labels per cluster, task %s, combined events'%(task_n))
    plt.savefig('./plots/clustering/t_%s/c_%i/combined_events'%(task_n, cluster_number))
    plt.clf()

# %%
from matplotlib import pyplot as plt
cluster_numbers = [10,50,100]


for event in events:
    clusters = {}

    for cluster_number in cluster_numbers:
        for i in range(0, cluster_number):
            clusters[i] = {0:0, 1:0, 2:0, 3:0}

        kmeans = KMeans(n_clusters=cluster_number, random_state=0, n_init="auto").fit(df)
        predicted = kmeans.labels_

        for i, cluster in enumerate(predicted):
            clusters[cluster][labels[i]] += 1

        dist_dict = {}
        for i, cluster in enumerate(clusters.values()):
            dist_dict[i] = (cluster[event])

        distlist = list(dist_dict.values())
        plt.plot(distlist)
        plt.ylabel("Number of datapoints")
        plt.xlabel("Cluster")
        plt.title('number of labels per cluster, task %s, event %i'%(task_n, event))
        plt.savefig('./plots/clustering/t_%s/c_%i/event_%i'%(task_n, cluster_number, event))
        plt.clf()

# %%
#distlist.sort()
distlist
# Out:
# [276,
#  522,
#  468,
#  0,
#  7,
#  86,
#  578,
#  0,
#  24,
#  504,
#  10,
#  2,
#  0,
#  3,
#  426,
#  0,
#  0,
#  36,
#  350,
#  200,
#  0,
#  4,
#  0,
#  614,
#  515,
#  877,
#  0,
#  1,
#  10,
#  4,
#  5,
#  7,
#  239,
#  290,
#  1,
#  25,
#  18,
#  2,
#  1,
#  16,
#  7,
#  1,
#  48,
#  433,
#  20,
#  1,
#  6,
#  0,
#  50,
#  551]

# %%
# Out:
# Text(0.5, 1.0, 'number of labels per cluster, task 1')

# %%
from tabulate import tabulate
table = [['cluster', 'label distribution', 'label percentage']]
print('task: %s, clusters: %i'%(task_n,cluster_number))
for i in clusters:
    perc = round(100* (max(clusters[i].values())/ sum(clusters[i].values())))
    if (max(clusters[i].values()) > 200):
        table.append([i, clusters[i], str(perc)+ '%'])
print(tabulate(table, tablefmt='fancy_grid'))
# Out:
# task: 2, clusters: 50
# ╒═════════╤════════════════════════════════╤══════════════════╕
# │ cluster │ label distribution             │ label percentage │
# ├─────────┼────────────────────────────────┼──────────────────┤
# │ 0       │ {0: 276, 1: 531, 2: 109, 3: 0} │ 58%              │
# ├─────────┼────────────────────────────────┼──────────────────┤
# │ 1       │ {0: 522, 1: 408, 2: 847, 3: 0} │ 48%              │
# ├─────────┼────────────────────────────────┼──────────────────┤
# │ 2       │ {0: 468, 1: 329, 2: 227, 3: 0} │ 46%              │
# ├─────────┼────────────────────────────────┼──────────────────┤
# │ 5       │ {0: 86, 1: 313, 2: 99, 3: 0}   │ 63%              │
# ├─────────┼────────────────────────────────┼──────────────────┤
# │ 6       │ {0: 578, 1: 458, 2: 550, 3: 0} │ 36%              │
# ├─────────┼────────────────────────────────┼──────────────────┤
# │ 9       │ {0: 504, 1: 430, 2: 288, 3: 0} │ 41%              │
# ├─────────┼────────────────────────────────┼──────────────────┤
# │ 14      │ {0: 426, 1: 401, 2: 147, 3: 0} │ 44%              │
# ├─────────┼────────────────────────────────┼──────────────────┤
# │ 17      │ {0: 36, 1: 59, 2: 397, 3: 0}   │ 81%              │
# ├─────────┼────────────────────────────────┼──────────────────┤
# │ 18      │ {0: 350, 1: 450, 2: 151, 3: 0} │ 47%              │
# ├─────────┼────────────────────────────────┼──────────────────┤
# │ 19      │ {0: 200, 1: 543, 2: 181, 3: 0} │ 59%              │
# ├─────────┼────────────────────────────────┼──────────────────┤
# │ 23      │ {0: 614, 1: 350, 2: 396, 3: 0} │ 45%              │
# ├─────────┼────────────────────────────────┼──────────────────┤
# │ 24      │ {0: 515, 1: 390, 2: 219, 3: 0} │ 46%              │
# ├─────────┼────────────────────────────────┼──────────────────┤
# │ 25      │ {0: 877, 1: 484, 2: 536, 3: 0} │ 46%              │
# ├─────────┼────────────────────────────────┼──────────────────┤
# │ 32      │ {0: 239, 1: 568, 2: 143, 3: 0} │ 60%              │
# ├─────────┼────────────────────────────────┼──────────────────┤
# │ 33      │ {0: 290, 1: 305, 2: 817, 3: 0} │ 58%              │
# ├─────────┼────────────────────────────────┼──────────────────┤
# │ 36      │ {0: 18, 1: 16, 2: 379, 3: 0}   │ 92%              │
# ├─────────┼────────────────────────────────┼──────────────────┤
# │ 42      │ {0: 48, 1: 13, 2: 265, 3: 0}   │ 81%              │
# ├─────────┼────────────────────────────────┼──────────────────┤
# │ 43      │ {0: 433, 1: 465, 2: 219, 3: 0} │ 42%              │
# ├─────────┼────────────────────────────────┼──────────────────┤
# │ 49      │ {0: 551, 1: 394, 2: 269, 3: 0} │ 45%              │
# ╘═════════╧════════════════════════════════╧══════════════════╛

# %%
import matplotlib.pyplot as plt

for i in clusters:
    perc = round(100* (max(clusters[i].values())/ sum(clusters[i].values())))
    if (max(clusters[i].values()) > 200):
        fig = plt.bar([0,1,2,3], clusters[i].values(), color='b')
        plt.title("Number of label occurences in cluster %i, task %s, number of clusters %i"%(i,task_n,cluster_number))
        plt.xticks(range(0,4))
        plt.xlabel("Label")
        plt.ylabel("Number of occurences in cluster")
        plt.savefig('./plots/clustering/t_%s/c_%i/cluster_%i.png'%((task_n,cluster_number,i)))
        plt.clf()

# %%
from sklearn.metrics import silhouette_score
score = silhouette_score(df, predicted, metric='euclidean')

# %%
print('Silhouette Score: %.3f' % score)
# Out:
# Silhouette Score: 0.382

# %%
from yellowbrick.cluster import KElbowVisualizer
#
# Instantiate the clustering model and visualizer
#
km = KMeans(random_state=42)
visualizer = KElbowVisualizer(km, k=(10,100))
 
visualizer.fit(df)        # Fit the data to the visualizer
visualizer.show()        # Finalize and render the figure
# Out:
# /Users/rubenotter/opt/anaconda3/lib/python3.8/site-packages/scikit_learn-1.2.0rc1-py3.8-macosx-11.1-arm64.egg/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/rubenotter/opt/anaconda3/lib/python3.8/site-packages/scikit_learn-1.2.0rc1-py3.8-macosx-11.1-arm64.egg/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/rubenotter/opt/anaconda3/lib/python3.8/site-packages/scikit_learn-1.2.0rc1-py3.8-macosx-11.1-arm64.egg/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <__array_function__ internals>:2, in where(*args, **kwargs)
#
# KeyboardInterrupt:
# Exception ignored in: 'sklearn.cluster._k_means_common._relocate_empty_clusters_dense'
# Traceback (most recent call last):
#   File "<__array_function__ internals>", line 2, in where
# KeyboardInterrupt:
# /Users/rubenotter/opt/anaconda3/lib/python3.8/site-packages/scikit_learn-1.2.0rc1-py3.8-macosx-11.1-arm64.egg/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/rubenotter/opt/anaconda3/lib/python3.8/site-packages/scikit_learn-1.2.0rc1-py3.8-macosx-11.1-arm64.egg/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/rubenotter/opt/anaconda3/lib/python3.8/site-packages/scikit_learn-1.2.0rc1-py3.8-macosx-11.1-arm64.egg/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/rubenotter/opt/anaconda3/lib/python3.8/site-packages/scikit_learn-1.2.0rc1-py3.8-macosx-11.1-arm64.egg/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/rubenotter/opt/anaconda3/lib/python3.8/site-packages/scikit_learn-1.2.0rc1-py3.8-macosx-11.1-arm64.egg/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
import os
import pandas as pd
import functions

# %%
path = './data/feats_lbls/lblr6/'
df = pd.DataFrame()

framesdict = {'2': {'0': 1563, '1': 9999999, '2': 1294, '3': 9999999},\
            '1' : {'0': 999999, '1': 0, '2': 2264, '3': 2441},\
            '4' : {'0' : 999999, '1': 0, '2': 9999999, '3': 9766},\
            '3': {'0': 999999, '1': 0, '2': 3020, '3': 3255}}

for filename in os.listdir(path):
    if filename.startswith('lbls'):
        file_df = pd.read_csv(path+ 'feats' + filename[4:], header = None)
        file_df['label'] = pd.read_csv(path+ 'lbls' + filename[4:], header = None)
        df= pd.concat([df, functions.get_frames(file_df, framesdict[filename[-5]])])
# Out:
# 1806 999999
# 2740 9999999
# 46 9999999
# 2754 9999999
# 0 9999999
# 6008 9999999
# 0 9999999
# 821 999999
# 2491 999999
# 2239 9999999
# 0 9999999
# 10442 999999
# 2666 9999999
# 1292 9999999
# 0 9999999
# 733 999999
# 7667 9999999
# 0 9999999
# 5446 9999999
# 0 9999999
# 601 999999
# 896 999999
# 736 999999

# %%
from sklearn import datasets
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from yellowbrick.cluster import SilhouetteVisualizer

a = 0
  
fig, ax = plt.subplots(2, 2, figsize=(15,8))
for i in [5,11,51,101]:
    '''
    Create KMeans instance for different number of clusters
    '''
    km = KMeans(n_clusters=i, init='k-means++', n_init=10, max_iter=100, random_state=42)
    #q, mod = divmod(i, 2)
    
    '''
    Create SilhouetteVisualizer instance with KMeans instance
    Fit the visualizer
    '''

    q = [0,1,0,1]
    mod = [0,0,1,1]


    
    visualizer = SilhouetteVisualizer(km, colors='yellowbrick', ax=ax[q[a]][mod[a]])

    a+=1

    visualizer.fit(df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/rubenotter/Desktop/school/master/graduation/eyes/code/proj1/Unsupervised-Gaze-Event-Discrimination/clustering 2.ipynb Cell 26 in <cell line: 9>()
#      <a href='vscode-notebook-cell:/Users/rubenotter/Desktop/school/master/graduation/eyes/code/proj1/Unsupervised-Gaze-Event-Discrimination/clustering%202.ipynb#X32sZmlsZQ%3D%3D?line=25'>26</a> visualizer = SilhouetteVisualizer(km, colors='yellowbrick', ax=ax[q[a]][mod[a]])
#      <a href='vscode-notebook-cell:/Users/rubenotter/Desktop/school/master/graduation/eyes/code/proj1/Unsupervised-Gaze-Event-Discrimination/clustering%202.ipynb#X32sZmlsZQ%3D%3D?line=27'>28</a> a+=1
# ---> <a href='vscode-notebook-cell:/Users/rubenotter/Desktop/school/master/graduation/eyes/code/proj1/Unsupervised-Gaze-Event-Discrimination/clustering%202.ipynb#X32sZmlsZQ%3D%3D?line=29'>30</a> visualizer.fit(df)
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/yellowbrick/cluster/silhouette.py:138, in SilhouetteVisualizer.fit(self, X, y, **kwargs)
#     132 # TODO: decide to use this method or the score method to draw.
#     133 # NOTE: Probably this would be better in score, but the standard score
#     134 # is a little different and I'm not sure how it's used.
#     136 if not check_fitted(self.estimator, is_fitted_by=self.is_fitted):
#     137     # Fit the wrapped estimator
# --> 138     self.estimator.fit(X, y, **kwargs)
#     140 # Get the properties of the dataset
#     141 self.n_samples_ = X.shape[0]
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/scikit_learn-1.2.0rc1-py3.8-macosx-11.1-arm64.egg/sklearn/cluster/_kmeans.py:1417, in KMeans.fit(self, X, y, sample_weight)
#    1390 """Compute k-means clustering.
#    1391
#    1392 Parameters
#    (...)
#    1413     Fitted estimator.
#    1414 """
#    1415 self._validate_params()
# -> 1417 X = self._validate_data(
#    1418     X,
#    1419     accept_sparse="csr",
#    1420     dtype=[np.float64, np.float32],
#    1421     order="C",
#    1422     copy=self.copy_x,
#    1423     accept_large_sparse=False,
#    1424 )
#    1426 self._check_params_vs_input(X)
#    1428 random_state = check_random_state(self.random_state)
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/scikit_learn-1.2.0rc1-py3.8-macosx-11.1-arm64.egg/sklearn/base.py:518, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     453 def _validate_data(
#     454     self,
#     455     X="no_validation",
#    (...)
#     459     **check_params,
#     460 ):
#     461     """Validate input data and set or check the `n_features_in_` attribute.
#     462
#     463     Parameters
#    (...)
#     516         validated.
#     517     """
# --> 518     self._check_feature_names(X, reset=reset)
#     520     if y is None and self._get_tags()["requires_y"]:
#     521         raise ValueError(
#     522             f"This {self.__class__.__name__} estimator "
#     523             "requires y to be passed, but the target y is None."
#     524         )
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/scikit_learn-1.2.0rc1-py3.8-macosx-11.1-arm64.egg/sklearn/base.py:385, in BaseEstimator._check_feature_names(self, X, reset)
#     365 """Set or check the `feature_names_in_` attribute.
#     366
#     367 .. versionadded:: 1.0
#    (...)
#     381        should set `reset=False`.
#     382 """
#     384 if reset:
# --> 385     feature_names_in = _get_feature_names(X)
#     386     if feature_names_in is not None:
#     387         self.feature_names_in_ = feature_names_in
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/scikit_learn-1.2.0rc1-py3.8-macosx-11.1-arm64.egg/sklearn/utils/validation.py:1886, in _get_feature_names(X)
#    1884 # mixed type of string and non-string is not supported
#    1885 if len(types) > 1 and "str" in types:
# -> 1886     raise TypeError(
#    1887         "Feature names are only supported if all input features have string names, "
#    1888         f"but your input has {types} as feature name / column name types. "
#    1889         "If you want feature names to be stored and validated, you must convert "
#    1890         "them all to strings, by using X.columns = X.columns.astype(str) for "
#    1891         "example. Otherwise you can remove feature / column names from your input "
#    1892         "data, or convert them all to a non-string data type."
#    1893     )
#    1895 # Only feature names of all strings are supported
#    1896 if len(types) == 1 and types[0] == "str":
#
# TypeError: Feature names are only supported if all input features have string names, but your input has ['int', 'str'] as feature name / column name types. If you want feature names to be stored and validated, you must convert them all to strings, by using X.columns = X.columns.astype(str) for example. Otherwise you can remove feature / column names from your input data, or convert them all to a non-string data type.

# %%
df.head()
# Out:
#               0         1         2         3         4          5
# 27880  0.290381  1.074079  0.696093 -0.003009  0.960599  36.788453
# 18614  0.361478  2.964660  0.033143  0.000111  0.992730  53.850761
# 14508  0.339216  2.034333  0.012064 -0.000027  0.399134  84.215803
# 16018  0.399516  0.284522  0.210560  0.000702  1.004804  35.755920
# 9170   0.056497 -1.704476  0.025865 -0.000173  0.241219  19.362806

# %%
path = './data/feats_lbls/lblr6/'
df = pd.DataFrame()

framesdict = {'2': {'0': 1563, '1': 9999999, '2': 1294, '3': 9999999},\
            '1' : {'0': 999999, '1': 0, '2': 2264, '3': 2441},\
            '4' : {'0' : 999999, '1': 0, '2': 9999999, '3': 9766},\
            '3': {'0': 999999, '1': 0, '2': 3020, '3': 3255}}

for filename in os.listdir(path):
    if filename.startswith('lbls'):
        file_df = pd.read_csv(path+ 'feats' + filename[4:], header = None)
        file_df['label'] = pd.read_csv(path+ 'lbls' + filename[4:], header = None)
        df= pd.concat([df, functions.get_frames(file_df, framesdict[filename[-5]])])
# Out:
# 1806 999999
# 2740 9999999
# 46 9999999
# 2754 9999999
# 0 9999999
# 6008 9999999
# 0 9999999
# 821 999999
# 2491 999999
# 2239 9999999
# 0 9999999
# 10442 999999
# 2666 9999999
# 1292 9999999
# 0 9999999
# 733 999999
# 7667 9999999
# 0 9999999
# 5446 9999999
# 0 9999999
# 601 999999
# 896 999999
# 736 999999

# %%
#df = df.drop('label', axis = 1)
df = functions.normalize(df)

# %%
from sklearn.metrics import silhouette_samples, silhouette_score
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np

df, y = functions.file_opener(task = 'all', labeler = 'all', seperated = True)
df = df.drop('task', axis = 1)
df = functions.normalize(df)

X = df.values

range_n_clusters = [10, 50, 100]

for n_clusters in range_n_clusters:
    # Create a subplot with 1 row and 2 columns
    fig, (ax1) = plt.subplots(1, 1)
    fig.set_size_inches(18, 7)

    # The 1st subplot is the silhouette plot
    # The silhouette coefficient can range from -1, 1 but in this example all
    # lie within [-0.1, 1]
    ax1.set_xlim([-0.1, 1])
    # The (n_clusters+1)*10 is for inserting blank space between silhouette
    # plots of individual clusters, to demarcate them clearly.
    ax1.set_ylim([0, len(X) + (n_clusters + 1) * 10])

    # Initialize the clusterer with n_clusters value and a random generator
    # seed of 10 for reproducibility.
    clusterer = KMeans(n_clusters=n_clusters, n_init="auto", random_state=10)
    cluster_labels = clusterer.fit_predict(X)

    # The silhouette_score gives the average value for all the samples.
    # This gives a perspective into the density and separation of the formed
    # clusters
    silhouette_avg = silhouette_score(X, cluster_labels)
    print(
        "For n_clusters =",
        n_clusters,
        "The average silhouette_score is :",
        silhouette_avg,
    )

    # Compute the silhouette scores for each sample
    sample_silhouette_values = silhouette_samples(X, cluster_labels)

    y_lower = 10
    for i in range(n_clusters):
        # Aggregate the silhouette scores for samples belonging to
        # cluster i, and sort them
        ith_cluster_silhouette_values = sample_silhouette_values[cluster_labels == i]

        ith_cluster_silhouette_values.sort()

        size_cluster_i = ith_cluster_silhouette_values.shape[0]
        y_upper = y_lower + size_cluster_i

        color = cm.nipy_spectral(float(i) / n_clusters)
        ax1.fill_betweenx(
            np.arange(y_lower, y_upper),
            0,
            ith_cluster_silhouette_values,
            facecolor=color,
            edgecolor=color,
            alpha=0.7,
        )

        # Label the silhouette plots with their cluster numbers at the middle
        ax1.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))

        # Compute the new y_lower for next plot
        y_lower = y_upper + 10  # 10 for the 0 samples

    ax1.set_title("The silhouette plot for the various clusters.")
    ax1.set_xlabel("The silhouette coefficient values")
    ax1.set_ylabel("Cluster label")

    # The vertical line for average silhouette score of all the values
    ax1.axvline(x=silhouette_avg, color="red", linestyle="--")

    ax1.set_yticks([])  # Clear the yaxis labels / ticks
    ax1.set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])



    plt.suptitle(
        "Silhouette analysis for KMeans clustering on sample data with n_clusters = %d"
        % n_clusters,
        fontsize=14,
        fontweight="bold",
    )

    plt.savefig('./plots/clustering/t_%s/silhouettes_%d'%(task_n,n_clusters))
# Out:
# For n_clusters = 10 The average silhouette_score is : 0.27079059096154784
# For n_clusters = 50 The average silhouette_score is : 0.24302626879733108
# For n_clusters = 100 The average silhouette_score is : 0.24115584249485852
